# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
from scipy import signal

# %%
df = pd.read_csv(r"C:\Users\Alina\Desktop\1111\33880011.dat", sep="\t", encoding = 'cp1251', skiprows=29, parse_dates=[['Date', 'Time']])
df
# Out:
#                   Date_Time  Samples  msec       sec           1           2  \
# 0       2037-07-05 05:21:02        0     0     0.000 -726.518127  646.312317
# 1       2037-07-05 05:21:02        1     2     0.002 -735.392517  627.951416
# 2       2037-07-05 05:21:02        2     4     0.004 -732.957031  620.783325
# 3       2037-07-05 05:21:02        3     6     0.006 -738.109375  645.517517
# 4       2037-07-05 05:21:02        4     8     0.008 -737.692627  668.026978
# ...                     ...      ...   ...       ...         ...         ...
# 1373131 2037-07-05 06:06:48  1373131   262  2746.262 -630.023804  523.872192
# 1373132 2037-07-05 06:06:48  1373132   264  2746.264 -628.651245  507.096924
# 1373133 2037-07-05 06:06:48  1373133   266  2746.266 -623.323120  516.322510
# 1373134 2037-07-05 06:06:48  1373134   268  2746.268 -640.466309  537.012939
# 1373135 2037-07-05 06:06:48  1373135   270  2746.270 -650.441772  525.072876
#
#                   3
# 0       -498.730743
# 1       -514.067078
# 2       -516.206604
# 3       -510.043976
# 4       -526.196411
# ...             ...
# 1373131 -479.159821
# 1373132 -479.733002
# 1373133 -431.460602
# 1373134 -410.549927
# 1373135 -441.998932
#
# [1373136 rows x 7 columns]

# %%
fig, axs = plt.subplots(3, 1, figsize=(20, 10))
names = ["1", "2", "3"]

comp = ["Z", "N", "E"]
for i in range(3):
    buff = df[names[i]]
    N = 351
    m = np.convolve(buff, np.ones(N)/N, mode='valid')
    m = buff[:len(m)]-m
    
    axs[i].plot(df["Date_Time"][:len(m)], m, 'k')
    axs[i].grid()
    axs[i].set_xlabel("UTC Datetime")
    axs[i].set_ylabel(comp[i]+" компонента, у.е. АЦП")
    axs[i].autoscale(enable=True, axis='y', tight=True)
    axs[i].autoscale(enable=True, axis='x', tight=True)
#     axs[i]
plt.show()

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
from scipy import signal

df = pd.read_csv(r"C:\Users\Alina\Desktop\1111\33880011.dat", sep="\t", encoding = 'cp1251', skiprows=29, parse_dates=[['Date', 'Time']])

fig, axs = plt.subplots(3, 1, figsize=(20, 10))
names = ["1", "2", "3"]

comp = ["Z", "N", "E"]
for i in range(3):
    buff = df[names[i]]
    
    N = 351
    m = np.convolve(buff, np.ones(N)/N, mode='valid')
    m = buff[:len(m)]-m
    
    axs[i].plot(m[10000:-20000], 'k')
    
    axs[i].grid()
    axs[i].set_xlabel("UTC Datetime")
    axs[i].set_ylabel(comp[i]+" компонента, у.е. АЦП")
    axs[i].autoscale(enable=True, axis='y', tight=True)
    axs[i].autoscale(enable=True, axis='x', tight=True)
#     axs[i].set_xlim(...)
plt.show()

# %%
## 1

df = pd.read_csv(r"C:\Users\Alina\Desktop\1111\33880011.dat", sep="\t", encoding = 'cp1251', skiprows=29, parse_dates=[['Date', 'Time']])

fig, axs = plt.subplots(3, 1, figsize=(20, 10))
names = ["1", "2", "3"]

comp = ["Z", "N", "E"]
for i in range(3):
    buff = df[names[i]]
    
    N = 351
    m = np.convolve(buff, np.ones(N)/N, mode='valid')
    m = buff[:len(m)]-m
    
    axs[i].plot(m[100000:-100000], 'k')
    
    axs[i].grid()
    axs[i].set_xlabel("UTC Datetime")
    axs[i].set_ylabel(comp[i]+" компонента, у.е. АЦП")
    axs[i].autoscale(enable=True, axis='y', tight=True)
    axs[i].autoscale(enable=True, axis='x', tight=True)
#     axs[i].set_xlim(...)
plt.show()

# %%
## 2

df = pd.read_csv(r"C:\Users\Alina\Desktop\1111\33890003.dat", sep="\t", encoding = 'cp1251', skiprows=29, parse_dates=[['Date', 'Time']])
fig, axs = plt.subplots(3, 1, figsize=(20, 10))
names = ["1", "2", "3"]

comp = ["Z", "N", "E"]
for i in range(3):
    buff = df[names[i]]
    
    N = 351
    m = np.convolve(buff, np.ones(N)/N, mode='valid')
    m = buff[:len(m)]-m
    
    axs[i].plot(m[500000:-500000], 'k')
    
    axs[i].grid()
    axs[i].set_xlabel("UTC Datetime")
    axs[i].set_ylabel(comp[i]+" компонента, у.е. АЦП")
    axs[i].autoscale(enable=True, axis='y', tight=True)
    axs[i].autoscale(enable=True, axis='x', tight=True)
#     axs[i].set_xlim(...)
plt.show()
# Out:
# C:\Users\Alina\AppData\Local\Temp\ipykernel_23676\1416437225.py:3: UserWarning: Parsing dates in %d.%m.%Y %H:%M:%S format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df = pd.read_csv(r"C:\Users\Alina\Desktop\1111\33890003.dat", sep="\t", encoding = 'cp1251', skiprows=29, parse_dates=[['Date', 'Time']])

# %%
## 3

df = pd.read_csv(r"C:\Users\Alina\Desktop\1111\33900015.dat", sep="\t", encoding = 'cp1251', skiprows=29, parse_dates=[['Date', 'Time']])
fig, axs = plt.subplots(3, 1, figsize=(20, 10))
names = ["1", "2", "3"]

comp = ["Z", "N", "E"]
for i in range(3):
    buff = df[names[i]]
    
    N = 351
    m = np.convolve(buff, np.ones(N)/N, mode='valid')
    m = buff[:len(m)]-m
    
    axs[i].plot(m[500000:-500000], 'k')
    
    axs[i].grid()
    axs[i].set_xlabel("UTC Datetime")
    axs[i].set_ylabel(comp[i]+" компонента, у.е. АЦП")
    axs[i].autoscale(enable=True, axis='y', tight=True)
    axs[i].autoscale(enable=True, axis='x', tight=True)
#     axs[i].set_xlim(...)
plt.show()

# %%
## 4 

df = pd.read_csv(r"C:\Users\Alina\Desktop\1111\33920011.dat", sep="\t", encoding = 'cp1251', skiprows=29, parse_dates=[['Date', 'Time']])

fig, axs = plt.subplots(3, 1, figsize=(20, 10))
names = ["1", "2", "3"]

comp = ["Z", "N", "E"]
for i in range(3):
    buff = df[names[i]]
    
    N = 351
    m = np.convolve(buff, np.ones(N)/N, mode='valid')
    m = buff[:len(m)]-m
    
    axs[i].plot(m[500000:-500000], 'k')
    
    axs[i].grid()
    axs[i].set_xlabel("UTC Datetime")
    axs[i].set_ylabel(comp[i]+" компонента, у.е. АЦП")
    axs[i].autoscale(enable=True, axis='y', tight=True)
    axs[i].autoscale(enable=True, axis='x', tight=True)
#     axs[i].set_xlim(...)
plt.show()
# Out:
# C:\Users\Alina\AppData\Local\Temp\ipykernel_23676\2539213557.py:3: UserWarning: Parsing dates in %d.%m.%Y %H:%M:%S format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df = pd.read_csv(r"C:\Users\Alina\Desktop\1111\33920011.dat", sep="\t", encoding = 'cp1251', skiprows=29, parse_dates=[['Date', 'Time']])

# %%
fs = 500
f, Pxx_den = signal.welch(m[500000:-500000], fs, nperseg=50000)
plt.semilogy(f, Pxx_den)
plt.ylim([0.5e-15, 1e9])
plt.xlabel('frequency [Hz]')
plt.ylabel('PSD [V**2/Hz]')
plt.show()

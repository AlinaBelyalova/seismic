# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %matplotlib ipympl
from matplotlib import pyplot as plt
import matplotlib.dates as mdates
import datetime
import os

# %%
df = pd.read_csv(r"C:\Users\Alina\Desktop\1111\33880011.dat", sep="\t", encoding = 'cp1251', skiprows=29, parse_dates=[['Date', 'Time', 'sec']])
df

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

file_paths = [
    r"C:\Users\Alina\Desktop\3388\33880380.dat",
    r"C:\Users\Alina\Desktop\3389\33890382.dat",
    r"C:\Users\Alina\Desktop\3390\33900381.dat",
    r"C:\Users\Alina\Desktop\3392\33920382.dat"
]


dfs = [pd.read_csv(file, sep="\t", encoding='cp1251', skiprows=29, parse_dates=[['Date', 'Time']]) for file in file_paths]

fig, axs = plt.subplots(3, 1, figsize=(10, 4))

names = ["1", "2", "3"]
comp = ["Z", "N", "E"]
colors = ['y', 'g', 'k', 'b']

for k in range(3):  
    for i, df in enumerate(dfs):  
        if k < len(names): 
            buff = df[names[k]]
            N = 10001
            if i == 0:
                buff = np.roll(buff, 50)
            
            
            m = np.convolve(buff, np.ones(N)/N, mode='valid')
            m = buff[:len(m)]-m
            m = m/np.max(np.abs(m))



        
            axs[k].plot(m[10000:-20000], color=colors[i], label=f'File {i+1}', linewidth=1, linestyle='-')

    axs[k].grid()
    #axs[k].set_xlabel("Sample")
    axs[k].set_xlabel("UTC Datetime")
    axs[k].set_ylabel(comp[k]+" компонента, у.е. АЦП")
    axs[k].autoscale(enable=True, axis='y', tight=True)
    axs[k].autoscale(enable=True, axis='x', tight=True)
    axs[k].set_xlim(0.5, len(m)-20000) 
    axs[k].set_ylim(-100000, 100000)  
    #axs[k].legend()
    
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
file_paths = [
    r"C:\Users\Alina\Desktop\3388\33880380.dat",
    r"C:\Users\Alina\Desktop\3389\33890382.dat",
    r"C:\Users\Alina\Desktop\3390\33900381.dat",
    r"C:\Users\Alina\Desktop\3392\33920382.dat"
]

dfs = [pd.read_csv(file, sep="\t", encoding='cp1251', skiprows=29, parse_dates=[['Date', 'Time']]) for file in file_paths]

# %%
names = ["3"]

colors = ['b', 'k', 'r', 'g']  
comp = ["Z", "N", "E"]

plt.figure(figsize=(10, 4)) 

for i, df in enumerate(dfs):
     
    buff = df[names[0]]  
#     m = buff
    N = 10001
    if i == 0:
        buff = np.roll(buff, 50)
#     if i == 3:
    m = np.convolve(buff, np.ones(N)/N, mode='valid')
#         m = buff[N//2:len(m)+N//2] - m
    m = buff[:len(m)] - m
#     else:
#         m = buff
    m = m/np.max(np.abs(m))
#     m -= np.mean(m)

    combined_datetime = pd.to_datetime(df['Date_Time']) + pd.to_timedelta(df['msec'], unit='ms')
    #file_name = os.path.basename(file_paths[i])
    parent_dir = os.path.basename(os.path.dirname(file_paths[i]))
    
    plt.plot(combined_datetime[:len(m)], m, color=colors[i],  label=f'{parent_dir}, linewidth=0.75, alpha=1)
    

start_time = "2024-02-02 10:17:34.48"
end_time = "2024-02-02 10:17:34.95"

#plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d %H:%M:%S'))
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%H:%M:%S'))
# plt.gca().xaxis.set_major_locator(mdates.DayLocator())
plt.xlim(pd.Timestamp(start_time), pd.Timestamp(end_time))

#plt.xlim()
plt.grid()
plt.xlabel("Sample")
plt.ylabel(names[0]+" компонента, у.е. АЦП")
plt.title('Компонента Z')
plt.autoscale(enable=True, axis='y', tight=True)
# plt.autoscale(enable=True, axis='x', tight=True)
plt.legend()
plt.show()
# Out:
#   Cell In[88], line 27
#     plt.plot(combined_datetime[:len(m)], m, color=colors[i],  label=f'{parent_dir}, linewidth=0.75, alpha=1)
#                                                                     ^
# SyntaxError: unterminated string literal (detected at line 27)

# %%
names = ["1"]
colors = ['b', 'k', 'r', 'g']
comp = ["Z", "N", "E"]


plt.figure(figsize=(10, 4))

for i, df in enumerate(dfs):

    buff = df[names[0]]
    
    N = 5001
    if i == 0:
        buff = np.roll(buff, 50)
        
    #m = np.convolve(buff, np.ones(N)/N, mode='valid')
    #m = buff[:len(m)] - m
    m = buff
    m = m / np.max(np.abs(m))

    combined_datetime = pd.to_datetime(df['Date_Time']) + pd.to_timedelta(df['msec'], unit='ms')
    parent_dir = os.path.basename(os.path.dirname(file_paths[i]))

    plt.plot(combined_datetime[:len(m)], m, color=colors[i], label=parent_dir, linewidth=0.75, alpha=1)

# start_time = "2024-02-02 10:17:34.48"
# end_time = "2024-02-02 10:17:34.95"

plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%H:%M:%S'))
# plt.xlim(pd.Timestamp(start_time), pd.Timestamp(end_time))

plt.grid()
plt.xlabel("UTC DateTime")
plt.ylabel(comp[0]+" компонента, у.е. АЦП")
plt.title('Компонента '+ comp[0])
plt.autoscale(enable=True, axis='y', tight=True)
plt.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
names = ["1"]
colors = ['b', 'k', 'r', 'g']
comp = ["Z", "N", "E"]


plt.figure(figsize=(10, 4))

for i, df in enumerate(dfs):

    buff = df[names[0]]
    N = 10001
    if i == 0:
        buff = np.roll(buff, 50)
    m = np.convolve(buff, np.ones(N)/N, mode='valid')
    m = buff[:len(m)] - m
    m = m / np.max(np.abs(m))

    combined_datetime = pd.to_datetime(df['Date_Time']) + pd.to_timedelta(df['msec'], unit='ms')
    parent_dir = os.path.basename(os.path.dirname(file_paths[i]))

    plt.plot(combined_datetime[:len(m)], m, color=colors[i], label=parent_dir, linewidth=0.75, alpha=1)

# start_time = "2024-02-02 10:17:34.48"
# end_time = "2024-02-02 10:17:34.95"

plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%H:%M:%S'))
# plt.xlim(pd.Timestamp(start_time), pd.Timestamp(end_time))

plt.grid()
plt.xlabel("UTC DateTime")
plt.ylabel(comp[0]+" компонента, у.е. АЦП")
plt.title('Компонента '+ comp[0])
#plt.autoscale(enable=True, axis='y', tight=True)
plt.ylim(-1, 1)
plt.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
names = ["3"]
colors = ['b', 'k', 'r', 'g']
comp = ["Z", "N", "E"]


plt.figure(figsize=(10, 4))

for i, df in enumerate(dfs):
    
    buff = df[names[0]]
    
    N = 10001
    if i == 0:
        
        buff = np.roll(buff, 50)
        
        
    #m = np.convolve(buff, np.ones(N)/N, mode='valid')
    #m = buff[:len(m)] - m
    m = buff
    #m = m / np.max(np.abs(m))

    combined_datetime = pd.to_datetime(df['Date_Time']) + pd.to_timedelta(df['msec'], unit='ms')
    parent_dir = os.path.basename(os.path.dirname(file_paths[i]))

    plt.plot(combined_datetime[:len(m)], m, color=colors[i], label=parent_dir, linewidth=0.75, alpha=1)

start_time = "2024-02-02 10:17:34.48"
end_time = "2024-02-02 10:17:34.95"

plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%H:%M:%S'))
plt.xlim(pd.Timestamp(start_time), pd.Timestamp(end_time))

plt.grid()
plt.xlabel("UTC DateTime")
plt.ylabel(comp[2]+" компонента, у.е. АЦП")
plt.title('Компонента '+ comp[2])
plt.autoscale(enable=True, axis='y', tight=True)

plt.legend(loc='upper right')
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
names = ["2"]
colors = ['b', 'k', 'r', 'g']
comp = ["Z", "N", "E"]


plt.figure(figsize=(10, 4))

for i, df in enumerate(dfs):
    
    buff = df[names[0]]
    
    N = 10001
    if i == 0:
        
        buff = np.roll(buff, 50)
        
        
    #m = np.convolve(buff, np.ones(N)/N, mode='valid')
    #m = buff[:len(m)] - m
    m = buff
    m = m / np.max(np.abs(m))

    combined_datetime = pd.to_datetime(df['Date_Time']) + pd.to_timedelta(df['msec'], unit='ms')
    parent_dir = os.path.basename(os.path.dirname(file_paths[i]))

    plt.plot(combined_datetime[:len(m)], m, color=colors[i], label=parent_dir, linewidth=0.75, alpha=1)

start_time = "2024-02-02 10:17:34.48"
end_time = "2024-02-02 10:17:34.95"

plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%H:%M:%S'))
plt.xlim(pd.Timestamp(start_time), pd.Timestamp(end_time))

plt.grid()
plt.xlabel("UTC DateTime")
plt.ylabel(comp[1]+" компонента, у.е. АЦП")
plt.title('Компонента '+ comp[1])
plt.autoscale(enable=True, axis='y', tight=True)
plt.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
names = ["1"]
colors = ['b', 'k', 'r', 'g']
comp = ["Z", "N", "E"]


plt.figure(figsize=(10, 4))

for i, df in enumerate(dfs):
    
    buff = df[names[0]]
    
    N = 10001
    if i == 0:
        
        buff = np.roll(buff, 50)
        
        
    #m = np.convolve(buff, np.ones(N)/N, mode='valid')
    #m = buff[:len(m)] - m
    m = buff
    m = m / np.max(np.abs(m))

    combined_datetime = pd.to_datetime(df['Date_Time']) + pd.to_timedelta(df['msec'], unit='ms')
    parent_dir = os.path.basename(os.path.dirname(file_paths[i]))

    plt.plot(combined_datetime[:len(m)], m, color=colors[i], label=parent_dir, linewidth=0.75, alpha=1)

start_time = "2024-02-02 10:17:34.48"
end_time = "2024-02-02 10:17:34.95"

plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%H:%M:%S'))
plt.xlim(pd.Timestamp(start_time), pd.Timestamp(end_time))

plt.grid()
plt.xlabel("UTC DateTime")
plt.ylabel(comp[0]+" компонента, у.е. АЦП")
plt.title('Компонента '+ comp[0])
plt.autoscale(enable=True, axis='y', tight=True)
plt.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
names = ["2"]
colors = ['b', 'k', 'r', 'g']
comp = ["Z", "N", "E"]


plt.figure(figsize=(10, 4))

for i, df in enumerate(dfs):

    buff = df[names[0]]
    N = 10001
    if i == 0:
        buff = np.roll(buff, 50)
    m = np.convolve(buff, np.ones(N)/N, mode='valid')
    m = buff[:len(m)] - m
    m = m / np.max(np.abs(m))

    combined_datetime = pd.to_datetime(df['Date_Time']) + pd.to_timedelta(df['msec'], unit='ms')
    parent_dir = os.path.basename(os.path.dirname(file_paths[i]))

    plt.plot(combined_datetime[:len(m)], m, color=colors[i], label=parent_dir, linewidth=0.75, alpha=1)

start_time = "2024-02-02 10:17:34.48"
end_time = "2024-02-02 10:17:34.95"

plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%H:%M:%S'))
plt.xlim(pd.Timestamp(start_time), pd.Timestamp(end_time))

plt.grid()
plt.xlabel("UTC DateTime")
plt.ylabel(comp[1]+" компонента, у.е. АЦП")
plt.title('Компонента '+ comp[1])
plt.autoscale(enable=True, axis='y', tight=True)
plt.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
names = ["3"]
colors = ['b', 'k', 'r', 'g']
comp = ["Z", "N", "E"]


plt.figure(figsize=(10, 4))

for i, df in enumerate(dfs):

    buff = df[names[0]]
    N = 10001
    if i == 0:
        buff = np.roll(buff, 50)
    m = np.convolve(buff, np.ones(N)/N, mode='valid')
    m = buff[:len(m)] - m
    m = m / np.max(np.abs(m))

    combined_datetime = pd.to_datetime(df['Date_Time']) + pd.to_timedelta(df['msec'], unit='ms')
    parent_dir = os.path.basename(os.path.dirname(file_paths[i]))

    plt.plot(combined_datetime[:len(m)], m, color=colors[i], label=parent_dir, linewidth=0.75, alpha=1)

start_time = "2024-02-02 10:17:34.48"
end_time = "2024-02-02 10:17:34.95"

plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%H:%M:%S'))
plt.xlim(pd.Timestamp(start_time), pd.Timestamp(end_time))

plt.grid()
plt.xlabel("UTC DateTime")
plt.ylabel(comp[2]+" компонента, у.е. АЦП")
plt.title('Компонента '+ comp[2])
#plt.autoscale(enable=True, axis='y', tight=True)
plt.ylim(-1, 1)
plt.legend()
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
pd.to_datetime(df['Date_Time'])

# %%
pd.to_timedelta(df['msec'], unit='ms')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal

file_paths = [
    r"C:\Users\Alina\Desktop\3388\33880380.dat",
    r"C:\Users\Alina\Desktop\3389\33890382.dat",
    r"C:\Users\Alina\Desktop\3390\33900381.dat",
    r"C:\Users\Alina\Desktop\3392\33920382.dat"
]

dfs = [pd.read_csv(file, sep="\t", encoding='cp1251', skiprows=29, parse_dates=[['Date', 'Time']]) for file in file_paths]

# %%
names = ["1"]  
colors = ['b', 'k', 'r', 'g']  

plt.figure(figsize=(6, 9))  
for i, df in enumerate(dfs):
    
   
    buff = df[names[0]]  
#     m = buff
    N = 10001
    if i == 0:
        buff = np.roll(buff, 50)
#     if i == 3:
    m = np.convolve(buff, np.ones(N)/N, mode='valid')
#         m = buff[N//2:len(m)+N//2] - m
    m = buff[:len(m)] - m
#     else:
#         m = buff
    m = m/np.max(np.abs(m))
#     m -= np.mean(m)
    parent_dir = os.path.basename(os.path.dirname(file_paths[i]))
    
    fs = 500
    f, Pxx_den = signal.welch(m[100:-100], fs, nperseg=500)
    plt.loglog(f, Pxx_den, color=colors[i], label=parent_dir)
plt.grid()

# plt.ylim([0.5e-15, 1e9])
plt.xlabel('frequency, [Hz]')
plt.ylabel('PSD [V**2/Hz]')

plt.xlim(0.1, 1000)
plt.title('Компонента '+ comp[0])
plt.legend()
plt.show()
# plt.ion()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
names = ["2"]  
colors = ['b', 'k', 'r', 'g']  

plt.figure(figsize=(6, 9))  
for i, df in enumerate(dfs):
    
   
    buff = df[names[0]]  
#     m = buff
    N = 10001
    if i == 0:
        buff = np.roll(buff, 50)
#     if i == 3:
    m = np.convolve(buff, np.ones(N)/N, mode='valid')
#         m = buff[N//2:len(m)+N//2] - m
    m = buff[:len(m)] - m
#     else:
#         m = buff
    m = m/np.max(np.abs(m))
#     m -= np.mean(m)
    parent_dir = os.path.basename(os.path.dirname(file_paths[i]))
    
    fs = 500
    f, Pxx_den = signal.welch(m[100:-100], fs, nperseg=500)
    plt.loglog(f, Pxx_den, color=colors[i], label=parent_dir)
plt.grid()

# plt.ylim([0.5e-15, 1e9])
plt.xlabel('frequency, [Hz]')
plt.ylabel('PSD [V**2/Hz]')

plt.xlim(0.1, 1000)
plt.title('Компонента '+ comp[1])
plt.legend()
plt.show()
# plt.ion()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
names = ["3"]  
colors = ['b', 'k', 'r', 'g']  

plt.figure(figsize=(6, 9))  
for i, df in enumerate(dfs):
    
   
    buff = df[names[0]]  
#     m = buff
    N = 10001
    if i == 0:
        buff = np.roll(buff, 50)
#     if i == 3:
    m = np.convolve(buff, np.ones(N)/N, mode='valid')
#         m = buff[N//2:len(m)+N//2] - m
    m = buff[:len(m)] - m
#     else:
#         m = buff
    m = m/np.max(np.abs(m))
#     m -= np.mean(m)
    parent_dir = os.path.basename(os.path.dirname(file_paths[i]))
    
    fs = 500
    f, Pxx_den = signal.welch(m[100:-100], fs, nperseg=50000)
    plt.loglog(f, Pxx_den, color=colors[i], label=parent_dir)
plt.grid()

# plt.ylim([0.5e-15, 1e9])
plt.xlabel('frequency, [Hz]')
plt.ylabel('PSD [V**2/Hz]')

plt.xlim(0.1, 1000)
plt.title('Компонента '+ comp[2])
plt.legend()
plt.show()
# plt.ion()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

file_paths = [
    r"C:\Users\Alina\Desktop\1111\33880011.dat",
    r"C:\Users\Alina\Desktop\1111\33890003.dat",
    r"C:\Users\Alina\Desktop\1111\33900015.dat",
    r"C:\Users\Alina\Desktop\1111\33920011.dat"
]

dfs = [pd.read_csv(file, sep="\t", encoding='cp1251', skiprows=29, parse_dates=[['Date', 'Time']]) for file in file_paths]


crosscorr_funcs = []
for i in range(len(dfs)):
    for j in range(i+1, len(dfs)):
        crosscorr_func = np.correlate(dfs[i]['1'][:20000], dfs[j]['1'][:20000], mode='full')
        crosscorr_funcs.append((i, j, crosscorr_func))


plt.figure(figsize=(10, 6))
for i, j, crosscorr_func in crosscorr_funcs:
    plt.plot(crosscorr_func, label=f'{i+1} and {j+1}')

plt.xlabel('Sample')
plt.ylabel('Correlation')
plt.title('VKF')
plt.legend()
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

file_paths = [
    r"C:\Users\Alina\Desktop\1111\33880011.dat",
    r"C:\Users\Alina\Desktop\1111\33890003.dat",
    r"C:\Users\Alina\Desktop\1111\33900015.dat",
    r"C:\Users\Alina\Desktop\1111\33920011.dat"
]

dfs = [pd.read_csv(file, sep="\t", encoding='cp1251', skiprows=29, parse_dates=[['Date', 'Time']]) for file in file_paths]


crosscorr_funcs = []
for i in range(len(dfs)):
    for j in range(i+1, len(dfs)):
        if j == 2: 
            shifted_series = dfs[j]['1'].shift(35000).fillna(0)
            crosscorr_func = np.correlate(dfs[i]['1'][:20000], shifted_series[:20000], mode='full')
        else:
            crosscorr_func = np.correlate(dfs[i]['1'][:20000], dfs[j]['1'][:20000], mode='full')
        crosscorr_funcs.append((i, j, crosscorr_func))


plt.figure(figsize=(10, 6))
for i, j, crosscorr_func in crosscorr_funcs:
    plt.plot(crosscorr_func, label=f'Files {i+1} and {j+1}')

plt.xlabel('Sample')
plt.ylabel('Correlation')
plt.title('VKF')
plt.legend()


plt.show()

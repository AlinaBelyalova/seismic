# %%
import pandas as pd
import glob

# %%
path = r"\\server\ngen_3_ВЫПОЛНЕНИЕ\2024.01 - (150) Масловское. Обработка и интерпретация\050 - Отчет\Передача материалов от 2024_02_29\Срезы кубов вдоль линий\*.csv"
fls = glob.glob(path)
fls
# Out:
# ['\\\\server\\ngen_3_ВЫПОЛНЕНИЕ\\2024.01 - (150) Масловское. Обработка и интерпретация\\050 - Отчет\\Передача материалов от 2024_02_29\\Срезы кубов вдоль линий\\ant_tracking[1m]_arbitary line 1.csv',
#  '\\\\server\\ngen_3_ВЫПОЛНЕНИЕ\\2024.01 - (150) Масловское. Обработка и интерпретация\\050 - Отчет\\Передача материалов от 2024_02_29\\Срезы кубов вдоль линий\\ant_tracking[1m]_arbitary line 10.csv',
#  '\\\\server\\ngen_3_ВЫПОЛНЕНИЕ\\2024.01 - (150) Масловское. Обработка и интерпретация\\050 - Отчет\\Передача материалов от 2024_02_29\\Срезы кубов вдоль линий\\ant_tracking[1m]_arbitary line 11.csv',
#  '\\\\server\\ngen_3_ВЫПОЛНЕНИЕ\\2024.01 - (150) Масловское. Обработка и интерпретация\\050 - Отчет\\Передача материалов от 2024_02_29\\Срезы кубов вдоль линий\\ant_tracking[1m]_arbitary line 12.csv',
# ...

# %%
for f in fls:
    df = pd.read_csv(f)
    df["Z"] = 430-df["Z"]
    df.to_csv(f)
